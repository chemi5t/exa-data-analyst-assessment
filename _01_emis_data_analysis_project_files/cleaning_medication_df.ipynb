# %% [markdown]
# # Summary
# registration_guid column maybe FK

# %% [markdown]
# # EMIS Data Analyst Project

# %%
import os
import pandas as pd

from data_extraction import DataExtractor as de

# %%
data_extractor = de()

# %% [markdown]
# # Cleaning of combined_medication.csv
#
# - code_id maybe the PK
# - emis_drug_guid from medication_df maybe same as registration_guid in patient_df

# %%
# Path to combined_medication.csv file
combined_medication_file_path = os.path.join(r'..\data', 'combined_medication.csv')

# Extract combined_medication.csv file
combined_medication_df = data_extractor.extract_from_csv(combined_medication_file_path)
# Out:
# c:\Users\chemi\AiCore_Projects\exa-data-analyst-assessment\_01_emis_data_analysis_project_files\data_extraction.py:23: DtypeWarning: Columns (1,2,3,4,8,16,17,20,21,22,26,30,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='utf-8')

# %%
display(combined_medication_df)
print("\n\n")
display(combined_medication_df.info())
dtype = combined_medication_df.dtypes
print (dtype)
# Out:
#            nhs_prescribing_agency                        emis_drug_guid  \
# 0       prescribed-at-gp-practice                                   NaN
# 1       prescribed-at-gp-practice                                   NaN
# 2       prescribed-at-gp-practice                                   NaN
# 3       prescribed-at-gp-practice                                   NaN
# 4       prescribed-at-gp-practice                                   NaN
# ...                           ...                                   ...
# 214011  prescribed-at-gp-practice  23DC3B2A-8984-4EDA-98B9-CFB9D2ECF361
# 214012  prescribed-at-gp-practice  AD382A01-3034-4EC9-9494-285CE5239AF1
# 214013  prescribed-at-gp-practice  9A4F1F64-F209-40BC-B529-C803E85821C4
# 214014  prescribed-at-gp-practice  97C9D388-B65D-4CD5-9B3F-0BAB037F14D2
# 214015  prescribed-at-gp-practice  234C68C2-00C9-4CF2-A301-7120D39214D1
#
#        authorisedissues_authorised_date authorisedissues_first_issue_date  \
# 0                   2005-04-13 00:00:00               2005-04-13 00:00:00
# 1                   2007-08-15 00:00:00               2007-08-15 00:00:00
# 2                   2005-05-10 00:00:00               2005-05-10 00:00:00
# 3                   2008-03-13 00:00:00               2008-03-13 00:00:00
# 4                   2008-06-14 00:00:00               2008-06-14 00:00:00
# ...                                 ...                               ...
# 214011                              NaN                               NaN
# 214012                              NaN                               NaN
# 214013                              NaN                               NaN
# 214014                              NaN                               NaN
# 214015                              NaN                               NaN
#
#        cancellation_reason  emis_code_id  confidential_flag  \
# 0                      NaN  2.662410e+14              False
# 1                      NaN  3.943341e+15              False
# 2                      NaN  2.215141e+15              False
# 3                      NaN  8.496410e+14              False
# 4                      NaN  1.467541e+15              False
# ...                    ...           ...                ...
# 214011                 NaN  8.380410e+14              False
# 214012                 NaN  1.418941e+15              False
# 214013                 NaN  9.114100e+13              False
# 214014                 NaN  1.563241e+15              False
# 214015                 NaN  3.196841e+15              False
#
#         consultation_source_emis_code_id  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 214011                               NaN
# 214012                               NaN
# 214013                               NaN
# 214014                               NaN
# 214015                               NaN
#
#        consultation_source_emis_original_term               dose  ...  \
# 0                                         NaN  APPLY TWICE A DAY  ...
# 1                                         NaN         2 PUFFS BD  ...
# 2                                         NaN          5 MLS QDS  ...
# 3                                         NaN           5 MLS OD  ...
# 4                                         NaN          10 MLS BD  ...
# ...                                       ...                ...  ...
# 214011                                    NaN     TAKE ONE DAILY  ...
# 214012                                    NaN        AS DIRECTED  ...
# 214013                                    NaN                 OD  ...
# 214014                                    NaN          ONE NIGHT  ...
# 214015                                    NaN        AS DIRECTED  ...
#
#                                        emis_original_term  sensitive_flag  \
# 0                                   Clotrimazole 1% cream           False
# 1       Clenil Modulite 100micrograms/dose inhaler (Ch...           False
# 2        Paracetamol 250mg/5ml oral suspension sugar free           False
# 3                        Loratadine 5mg/5ml oral solution           False
# 4        Trimethoprim 50mg/5ml oral suspension sugar free           False
# ...                                                   ...             ...
# 214011                         Lisinopril  Tablets  20 mg           False
# 214012  Tetanus Immunoglobulin  Injection  250 iu/ml p...           False
# 214013                           Atenolol  Tablets  50 mg           False
# 214014                         Zopiclone  Tablets  7.5 mg           False
# 214015  Fortisip Bottle  Liquid Feed (Mixed Flavours) ...           False
#
#         sensitive_patient_flag snomed_concept_id snomed_description_id  \
# 0                        False      3.262030e+08          1.077377e+17
# 1                        False      1.061821e+16          5.243830e+16
# 2                        False      3.902461e+16          1.615391e+15
# 3                        False      3.889671e+16          1.574471e+15
# 4                        False      3.902231e+16          1.614851e+15
# ...                        ...               ...                   ...
# 214011                   False      3.188600e+08          5.697490e+16
# 214012                   False      9.478811e+15          3.098140e+16
# 214013                   False      3.184200e+08          5.691190e+16
# 214014                   False      3.211750e+08          5.691350e+16
# 214015                   False               NaN                   NaN
#
#        fhir_medication_status cancellation_date nhs_prescription_type  \
# 0                   completed               NaN                 acute
# 1                      active               NaN                repeat
# 2                   completed               NaN                 acute
# 3                   completed               NaN                 acute
# 4                   completed               NaN                 acute
# ...                       ...               ...                   ...
# 214011              completed               NaN                repeat
# 214012              completed               NaN                 acute
# 214013              completed               NaN                repeat
# 214014              completed               NaN                repeat
# 214015              completed               NaN                repeat
#
#                        uom uom_dmd
# 0                  gram(s)     NaN
# 1                  inhaler     NaN
# 2                       ml     NaN
# 3                       ml     NaN
# 4                       ml     NaN
# ...                    ...     ...
# 214011           tablet(s)     NaN
# 214012  pre-filled syrg(s)     NaN
# 214013              tablet     NaN
# 214014           tablet(s)     NaN
# 214015           bottle(s)     NaN
#
# [214016 rows x 63 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214016 entries, 0 to 214015
# Data columns (total 63 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   nhs_prescribing_agency                    214016 non-null  object
#  1   emis_drug_guid                            155340 non-null  object
#  2   authorisedissues_authorised_date          58676 non-null   object
#  3   authorisedissues_first_issue_date         53614 non-null   object
#  4   cancellation_reason                       218 non-null     object
#  5   emis_code_id                              214012 non-null  float64
#  6   confidential_flag                         214016 non-null  bool
#  7   consultation_source_emis_code_id          24 non-null      float64
#  8   consultation_source_emis_original_term    24 non-null      object
#  9   dose                                      214016 non-null  object
#  10  emis_medication_status                    58676 non-null   float64
#  11  dummy_patient_flag                        214016 non-null  bool
#  12  duration_in_days                          214016 non-null  int64
#  13  duration_uom                              214016 non-null  object
#  14  effective_date                            214016 non-null  object
#  15  effective_date_precision                  214016 non-null  object
#  16  emis_issue_method                         155340 non-null  object
#  17  emis_mostrecent_issue_date                58573 non-null   object
#  18  emis_prescription_type                    214016 non-null  object
#  19  emis_registration_organisation_guid       214016 non-null  object
#  20  emis_encounter_guid                       24 non-null      object
#  21  exa_encounter_guid                        24 non-null      object
#  22  end_date                                  58573 non-null   object
#  23  emis_enteredby_userinrole_guid            214016 non-null  object
#  24  exa_prescription_guid                     0 non-null       float64
#  25  estimated_nhs_cost                        155340 non-null  float64
#  26  exa_drug_guid                             155340 non-null  object
#  27  medication_guid                           214016 non-null  object
#  28  exa_medication_guid                       214016 non-null  object
#  29  fhir_medication_intent                    214016 non-null  object
#  30  exa_mostrecent_issue_date                 53632 non-null   object
#  31  max_nextissue_days                        8 non-null       float64
#  32  min_nextissue_days                        8 non-null       float64
#  33  non_regular_and_current_active_flag       214016 non-null  bool
#  34  number_authorised                         211 non-null     float64
#  35  number_of_issues                          58676 non-null   float64
#  36  opt_out_93c1_flag                         214016 non-null  bool
#  37  opt_out_9nd19nu09nu4_flag                 214016 non-null  bool
#  38  opt_out_9nd19nu0_flag                     214016 non-null  bool
#  39  opt_out_9nu0_flag                         214016 non-null  bool
#  40  emis_medication_organisation_guid         214016 non-null  object
#  41  other_code                                8614 non-null    object
#  42  other_code_system                         8614 non-null    object
#  43  prescribed_as_contraceptive_flag          214016 non-null  bool
#  44  privately_prescribed_flag                 214016 non-null  bool
#  45  quantity                                  214016 non-null  float64
#  46  recorded_date                             214016 non-null  object
#  47  registration_guid                         214016 non-null  object
#  48  regular_and_current_active_flag           214016 non-null  bool
#  49  regular_current_active_and_inactive_flag  214016 non-null  bool
#  50  regular_patient_flag                      214016 non-null  bool
#  51  reimburse_type                            214016 non-null  int64
#  52  review_date                               113119 non-null  object
#  53  emis_original_term                        214016 non-null  object
#  54  sensitive_flag                            214016 non-null  bool
#  55  sensitive_patient_flag                    214016 non-null  bool
#  56  snomed_concept_id                         205398 non-null  float64
#  57  snomed_description_id                     205398 non-null  float64
#  58  fhir_medication_status                    214016 non-null  object
#  59  cancellation_date                         231 non-null     object
#  60  nhs_prescription_type                     214016 non-null  object
#  61  uom                                       213320 non-null  object
#  62  uom_dmd                                   0 non-null       float64
# dtypes: bool(14), float64(13), int64(2), object(34)
# memory usage: 82.9+ MB
# None
# nhs_prescribing_agency                object
# emis_drug_guid                        object
# authorisedissues_authorised_date      object
# authorisedissues_first_issue_date     object
# cancellation_reason                   object
#                                       ...
# fhir_medication_status                object
# cancellation_date                     object
# nhs_prescription_type                 object
# uom                                   object
# uom_dmd                              float64
# Length: 63, dtype: object

# %%
print(combined_medication_df['emis_code_id'].unique())
print(len(combined_medication_df['emis_code_id'].unique()))
# Out:
# [2.662410e+14 3.943341e+15 2.215141e+15 ... 4.904410e+14 3.030541e+15
#  1.370410e+14]
# 2665

# %%
print(combined_medication_df['emis_drug_guid'].unique())
print(len(combined_medication_df['emis_drug_guid'].unique()))
# Out:
# [nan '234C68C2-00C9-4CF2-A301-7120D39214D1'
#  'D36F6B6A-CCAB-4F67-8C8C-97768F8B5C00' ...
#  '23DC3B2A-8984-4EDA-98B9-CFB9D2ECF361'
#  'AD382A01-3034-4EC9-9494-285CE5239AF1'
#  '97C9D388-B65D-4CD5-9B3F-0BAB037F14D2']
# 53633
